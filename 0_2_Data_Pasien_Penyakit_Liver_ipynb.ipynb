# %% [markdown]
# <a href="https://colab.research.google.com/github/sitiluthfiatinsolihah/BelajarCloneRespository/blob/main/0_2_Data_Pasien_Penyakit_Liver_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
path_="/content/drive/MyDrive/Machine Learning/Data Pasien penyakit liver.csv"
dataset=pd.read_csv(path_)
dataset
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65       0              0.7               0.1                   187
# 1     62       1             10.9               5.5                   699
# 2     62       1              7.3               4.1                   490
# 3     58       1              1.0               0.4                   182
# 4     72       1              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 574   60       1              0.5               0.1                   500
# 575   40       1              0.6               0.1                    98
# 576   52       1              0.8               0.2                   245
# 577   31       1              1.3               0.5                   184
# 578   38       1              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
dataset.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65       0              0.7               0.1                   187
# 1   62       1             10.9               5.5                   699
# 2   62       1              7.3               4.1                   490
# 3   58       1              1.0               0.4                   182
# 4   72       1              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
plt.scatter(dataset['Alkaline_Phosphotase'],dataset['Direct_Bilirubin'])

# %%
plt.scatter(dataset['Albumin'],dataset['Direct_Bilirubin'])

# %%
dataset.dtypes
# Out:
# Age                             int64
# Gender                          int64
# Total_Bilirubin               float64
# Direct_Bilirubin              float64
# Alkaline_Phosphotase            int64
# Alamine_Aminotransferase        int64
# Aspartate_Aminotransferase      int64
# Total_Protiens                float64
# Albumin                       float64
# Albumin_and_Globulin_Ratio    float64
# Dataset                         int64
# dtype: object

# %%
X=dataset[['Direct_Bilirubin','Albumin']]
Y=dataset['Alkaline_Phosphotase']

# %%
X
# Out:
#      Direct_Bilirubin  Albumin
# 0                 0.1      3.3
# 1                 5.5      3.2
# 2                 4.1      3.3
# 3                 0.4      3.4
# 4                 2.0      2.4
# ..                ...      ...
# 574               0.1      1.6
# 575               0.1      3.2
# 576               0.2      3.2
# 577               0.5      3.4
# 578               0.3      4.4
#
# [579 rows x 2 columns]

# %%
Y
# Out:
# 0      187
# 1      699
# 2      490
# 3      182
# 4      195
#       ...
# 574    500
# 575     98
# 576    245
# 577    184
# 578    216
# Name: Alkaline_Phosphotase, Length: 579, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
len(X_train)
# Out:
# 463

# %%
len(X_test)
# Out:
# 116

# %%
X_train
# Out:
#      Direct_Bilirubin  Albumin
# 105               2.3      2.6
# 109               0.1      2.8
# 373               0.2      3.0
# 87                0.2      3.1
# 455               0.5      1.5
# ..                ...      ...
# 303               1.0      2.4
# 549               4.2      2.7
# 2                 4.1      3.3
# 208               0.3      2.8
# 434               0.2      1.4
#
# [463 rows x 2 columns]

# %%
X_test
# Out:
#      Direct_Bilirubin  Albumin
# 312               0.2      3.7
# 175               0.2      4.0
# 378               0.1      3.2
# 348               0.2      4.3
# 475               1.6      3.2
# ..                ...      ...
# 270               0.2      4.7
# 35                0.4      3.3
# 572               8.2      2.2
# 314               2.2      4.5
# 3                 0.4      3.4
#
# [116 rows x 2 columns]

# %%
Y_train
# Out:
# 105    145
# 109    486
# 373    202
# 87     298
# 455    686
#       ...
# 303    588
# 549    232
# 2      490
# 208    220
# 434    162
# Name: Alkaline_Phosphotase, Length: 463, dtype: int64

# %%
Y_test
# Out:
# 312    182
# 175    198
# 378    172
# 348    144
# 475    186
#       ...
# 270    262
# 35     482
# 572    289
# 314    216
# 3      182
# Name: Alkaline_Phosphotase, Length: 116, dtype: int64
