# %% [markdown]
# <a href="https://colab.research.google.com/github/sitiluthfiatinsolihah/BelajarCloneRespository/blob/main/0_3_Data_Pasien_Penyakit_Liver.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
path_="/content/drive/MyDrive/Machine Learning/Data Pasien penyakit liver.csv"
dataset=pd.read_csv(path_)
dataset
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65       0              0.7               0.1                   187
# 1     62       1             10.9               5.5                   699
# 2     62       1              7.3               4.1                   490
# 3     58       1              1.0               0.4                   182
# 4     72       1              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 574   60       1              0.5               0.1                   500
# 575   40       1              0.6               0.1                    98
# 576   52       1              0.8               0.2                   245
# 577   31       1              1.3               0.5                   184
# 578   38       1              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
dataset.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65       0              0.7               0.1                   187
# 1   62       1             10.9               5.5                   699
# 2   62       1              7.3               4.1                   490
# 3   58       1              1.0               0.4                   182
# 4   72       1              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
plt.scatter(dataset['Total_Protiens'],dataset['Albumin'])

# %%
plt.scatter(dataset['Alkaline_Phosphotase'],dataset['Albumin'])

# %%
dataset.dtypes
# Out:
# Age                             int64
# Gender                          int64
# Total_Bilirubin               float64
# Direct_Bilirubin              float64
# Alkaline_Phosphotase            int64
# Alamine_Aminotransferase        int64
# Aspartate_Aminotransferase      int64
# Total_Protiens                float64
# Albumin                       float64
# Albumin_and_Globulin_Ratio    float64
# Dataset                         int64
# dtype: object

# %%
X=dataset[['Albumin','Alkaline_Phosphotase']]
Y=dataset['Total_Protiens']

# %%
X
# Out:
#      Albumin  Alkaline_Phosphotase
# 0        3.3                   187
# 1        3.2                   699
# 2        3.3                   490
# 3        3.4                   182
# 4        2.4                   195
# ..       ...                   ...
# 574      1.6                   500
# 575      3.2                    98
# 576      3.2                   245
# 577      3.4                   184
# 578      4.4                   216
#
# [579 rows x 2 columns]

# %%
Y
# Out:
# 0      6.8
# 1      7.5
# 2      7.0
# 3      6.8
# 4      7.3
#       ...
# 574    5.9
# 575    6.0
# 576    6.4
# 577    6.8
# 578    7.3
# Name: Total_Protiens, Length: 579, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
len(X_train)
# Out:
# 405

# %%
len(X_test)
# Out:
# 174

# %%
X_train
# Out:
#      Albumin  Alkaline_Phosphotase
# 330      4.0                   350
# 171      3.3                   298
# 47       2.8                   230
# 304      2.3                   174
# 246      2.6                   202
# ..       ...                   ...
# 567      3.0                   215
# 427      2.9                   236
# 294      4.4                   159
# 144      2.9                   189
# 5        4.4                   208
#
# [405 rows x 2 columns]

# %%
X_test
# Out:
#      Albumin  Alkaline_Phosphotase
# 438      1.9                   298
# 272      4.1                   180
# 523      3.4                   298
# 158      2.0                   196
# 224      4.0                   120
# ..       ...                   ...
# 103      3.3                   225
# 442      2.7                   181
# 461      2.0                   270
# 200      2.4                   218
# 479      4.3                   182
#
# [174 rows x 2 columns]

# %%
Y_train
# Out:
# 330    7.4
# 171    6.6
# 47     4.9
# 304    4.6
# 246    5.0
#       ...
# 567    6.9
# 427    6.7
# 294    6.9
# 144    5.6
# 5      7.6
# Name: Total_Protiens, Length: 405, dtype: float64

# %%
Y_test
# Out:
# 438    4.6
# 272    8.2
# 523    7.1
# 158    5.8
# 224    7.9
#       ...
# 103    6.1
# 442    5.5
# 461    5.1
# 200    5.0
# 479    7.8
# Name: Total_Protiens, Length: 174, dtype: float64
