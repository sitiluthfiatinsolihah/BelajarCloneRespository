# %% [markdown]
# <a href="https://colab.research.google.com/github/sitiluthfiatinsolihah/BelajarCloneRespository/blob/main/20210120015_Siti_Luthfiatin_Solihah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-62eac36a-18c7-4d80-a336-beb858cd287e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-62eac36a-18c7-4d80-a336-beb858cd287e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Gantilah 'nama_file.xlsx' dengan nama file Excel yang diunggah
dataset = pd.read_excel('Data_Tanaman_Padi_Sumatera_version_1.xlsx')

# Buat DataFrame atau tambahkan data ke DataFrame yang sudah ada
# Misalnya, jika Anda ingin menambahkannya ke DataFrame yang sudah ada:
# existing_dataframe = existing_dataframe.append(data_excel)

# Tampilkan data Excel dalam bentuk DataFrame
dataset
# Out:
#     Provinsi  Tahun    Produksi  Luas Panen  Curah hujan  Kelembapan  \
# 0       Aceh   1993  1329536.00   323589.00       1627.0       82.00
# 1       Aceh   1994  1299699.00   329041.00       1521.0       82.12
# 2       Aceh   1995  1382905.00   339253.00       1476.0       82.72
# 3       Aceh   1996  1419128.00   348223.00       1557.0       83.00
# 4       Aceh   1997  1368074.00   337561.00       1339.0       82.46
# ..       ...    ...         ...         ...          ...         ...
# 219  Lampung   2016  3831923.00   390799.00       2317.6       79.40
# 220  Lampung   2017  4090654.00   396559.00       1825.1       77.04
# 221  Lampung   2018  2488641.91   511940.93       1385.8       76.05
# 222  Lampung   2019  2164089.33   464103.42       1706.4       78.03
# 223  Lampung   2020  2604913.29   545149.05       2211.3       75.80
#
#      Suhu rata-rata
# 0             26.06
# 1             26.92
# 2             26.27
# 3             26.08
# 4             26.31
# ...

# %%
dataset.head()
# Out:
#   Provinsi  Tahun   Produksi  Luas Panen  Curah hujan  Kelembapan  \
# 0     Aceh   1993  1329536.0    323589.0       1627.0       82.00
# 1     Aceh   1994  1299699.0    329041.0       1521.0       82.12
# 2     Aceh   1995  1382905.0    339253.0       1476.0       82.72
# 3     Aceh   1996  1419128.0    348223.0       1557.0       83.00
# 4     Aceh   1997  1368074.0    337561.0       1339.0       82.46
#
#    Suhu rata-rata
# 0           26.06
# 1           26.92
# 2           26.27
# 3           26.08
# 4           26.31

# %%
dataset.shape
# Out:
# (224, 7)

# %%
dataset.isnull().sum()
# Out:
# Provinsi          0
# Tahun             0
# Produksi          0
# Luas Panen        0
# Curah hujan       0
# Kelembapan        0
# Suhu rata-rata    0
# dtype: int64

# %%
dataset.max()
# Out:
# Provinsi          Sumatera Utara
# Tahun                       2020
# Produksi               4881089.0
# Luas Panen              872737.0
# Curah hujan               5522.0
# Kelembapan                  90.6
# Suhu rata-rata             29.85
# dtype: object

# %%
dataset.min()
# Out:
# Provinsi              Aceh
# Tahun                 1993
# Produksi           42938.0
# Luas Panen        63142.04
# Curah hujan          222.5
# Kelembapan            54.2
# Suhu rata-rata       22.19
# dtype: object

# %%
dataset.describe()
# Out:
#              Tahun      Produksi     Luas Panen  Curah hujan  Kelembapan  \
# count   224.000000  2.240000e+02     224.000000   224.000000  224.000000
# mean   2006.500000  1.679701e+06  374349.966920  2452.490759   80.948705
# std       8.095838  1.161387e+06  232751.161987  1031.972625    4.878680
# min    1993.000000  4.293800e+04   63142.040000   222.500000   54.200000
# 25%    1999.750000  5.488570e+05  146919.500000  1703.525000   78.975000
# 50%    2006.500000  1.667773e+06  373551.500000  2315.700000   82.375000
# 75%    2013.250000  2.436851e+06  514570.250000  3039.700000   84.000000
# max    2020.000000  4.881089e+06  872737.000000  5522.000000   90.600000
#
#        Suhu rata-rata
# count      224.000000
# mean        26.801964
# std          1.197041
# min         22.190000
# 25%         26.177500
# 50%         26.730000
# 75%         27.200000
# max         29.850000

# %%
data=dataset.dropna()

# %%
data.shape
# Out:
# (224, 7)

# %%
dataset.dropna(axis=0,subset=['Produksi','Kelembapan'],inplace=True)

# %%
dataset.shape
# Out:
# (224, 7)

# %%
y=data['Produksi']
y
# Out:
# 0      1329536.00
# 1      1299699.00
# 2      1382905.00
# 3      1419128.00
# 4      1368074.00
#           ...
# 219    3831923.00
# 220    4090654.00
# 221    2488641.91
# 222    2164089.33
# 223    2604913.29
# Name: Produksi, Length: 224, dtype: float64

# %%
fitur=['Produksi','Kelembapan']
x=dataset[fitur]
x
# Out:
#        Produksi  Kelembapan
# 0    1329536.00       82.00
# 1    1299699.00       82.12
# 2    1382905.00       82.72
# 3    1419128.00       83.00
# 4    1368074.00       82.46
# ..          ...         ...
# 219  3831923.00       79.40
# 220  4090654.00       77.04
# 221  2488641.91       76.05
# 222  2164089.33       78.03
# 223  2604913.29       75.80
#
# [224 rows x 2 columns]
